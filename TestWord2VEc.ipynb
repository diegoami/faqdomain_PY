# %%
from bd_gensim.doc2vec_facade import Doc2VecFacade
import yaml

# %%
config = yaml.safe_load(open("config.yml"))
data_dir = config['data_dir']
models_dir = config['models_dir']

# %%
doc2VecFacade = Doc2VecFacade(models_dir)

# %%
doc2VecFacade.load_models()

# %%
model = doc2VecFacade.model

# %%
cw_l = []
for word, vocab_obj in model.wv.vocab.items():
    cw_l.append((word, vocab_obj.count))
cw_s = sorted(cw_l, key=lambda x : x[1], reverse=True)

# %%
cw_s
# Out:
# [('erhalten', 1336),
#  ('konto', 1321),
#  ('bank', 1212),
#  ('didibank', 1046),
#  ('nutzen', 1007),
#  ('online-banking', 919),
#  ('kunde', 896),
#  ('didi', 851),
#  ('finden', 790),
#  ('datum', 742),
#  ('karten', 670),
#  ('erfolgen', 595),
#  ('benötigen', 587),
#  ('kreditkarte', 583),
#  ('ambibank', 573),
#  ('girokonto', 562),
#  ('pin', 537),
#  ('kredit', 537),
#  ('poltawien', 527),
#  ('transaktion', 516),
#  ('information', 512),
#  ('überweisung', 496),
#  ('automatisch', 484),
#  ('ändern', 483),
#  ('zusätzlich', 479),
#  ('fall', 479),
#  ('betragen', 470),
#  ('beachten', 469),
#  ('stehen', 461),
#  ('direkt', 457),
#  ('aktuell', 454),
#  ('geld', 454),
#  ('zins', 452),
#  ('zahlung', 440),
#  ('einfach', 427),
#  ('euro', 426),
#  ('banken', 424),
#  ('kosten', 420),
#  ('möglichkeit', 417),
#  ('gelten', 416),
#  ('verwenden', 414),
#  ('auftrag', 410),
#  ('kostenlos', 388),
#  ('angeben', 384),
#  ('beantragen', 379),
#  ('sichern', 376),
# ...

# %%
model.most_similar('v_pay',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('didibankcard', 0.9546463489532471),
#  ('bargeldlos_bezahlen', 0.9544440507888794),
#  ('girocard_v_pay', 0.9528388977050781),
#  ('didibank-bankcard', 0.9490991234779358),
#  ('weltweit', 0.9464023113250732),
#  ('akzeptanzstellen', 0.9417233467102051),
#  ('tankstelle', 0.9331265687942505),
#  ('kontaktlos-symbol', 0.9252417683601379),
#  ('kontaktlos_bezahlen', 0.9184434413909912),
#  ('paypass', 0.9167722463607788),
#  ('near_field_communication', 0.9142665863037109),
#  ('maestro', 0.9133284091949463),
#  ('mastercard_visa', 0.9102078080177307),
#  ('american_express', 0.9089125990867615),
#  ('reise', 0.9088990688323975),
#  ('visa_mastercard', 0.9042991399765015),
# ...

# %%
cw_s[1000:]
# Out:
# [('umstand', 39),
#  ('zahlungseingang', 39),
#  ('kartennummer', 39),
#  ('planen', 39),
#  ('nötigen', 39),
#  ('blicken', 39),
#  ('finanzinstitut', 39),
#  ('überall', 39),
#  ('erstatten', 39),
#  ('wohnung', 39),
#  ('beitrag', 39),
#  ('giro', 39),
#  ('steuererklärung', 39),
#  ('phishing', 39),
#  ('kauf', 39),
#  ('kapital', 39),
#  ('shortpin', 39),
#  ('aufrufen', 38),
#  ('einzelne', 38),
#  ('anklicken', 38),
#  ('eintrag', 38),
#  ('einreichung', 38),
#  ('inland', 38),
#  ('deutsche_post', 38),
#  ('steuerbescheinigung', 38),
#  ('europa', 38),
#  ('gläubiger-id', 38),
#  ('maximal_euro', 38),
#  ('anfällen', 38),
#  ('zeitlich', 38),
#  ('aufforderung', 38),
#  ('selbständig', 38),
#  ('kaufen_verkaufen', 38),
#  ('rente', 38),
#  ('vorlegen', 38),
#  ('widersprechen', 38),
#  ('haften', 38),
#  ('gehalt', 38),
#  ('erzielen', 38),
#  ('genutzt', 38),
#  ('geldanlagen', 38),
#  ('drücken', 37),
#  ('sorgen', 37),
#  ('kontrollieren', 37),
#  ('starmoney', 37),
# ...

# %%
cw_s[2000:]
# Out:
# [('vertraglich', 18),
#  ('diebstahl', 18),
#  ('id', 18),
#  ('formularcenter', 18),
#  ('innerhalb_monat', 18),
#  ('finden_iban_bic', 18),
#  ('transparenz', 18),
#  ('tippen', 18),
#  ('erbringen', 18),
#  ('versicherungsschutz', 18),
#  ('zugrunde', 18),
#  ('auflösung', 18),
#  ('portemonnaie', 18),
#  ('eltern', 18),
#  ('bild', 18),
#  ('betroffen', 18),
#  ('überprüfung', 18),
#  ('kontonummer_bankleitzahl', 18),
#  ('verheiraten', 18),
#  ('sicherungseinrichtung', 18),
#  ('bgb', 18),
#  ('schnellstmöglich', 18),
#  ('tan_per_sms', 18),
#  ('gmbh_oglietzen', 18),
#  ('genießen', 18),
#  ('schaffen', 18),
#  ('tabelle', 18),
#  ('kraft', 18),
#  ('festschreiben', 18),
#  ('umfassen', 18),
#  ('sagen', 18),
#  ('verringern', 18),
#  ('mindestbetrag', 18),
#  ('erwirtschaften', 18),
#  ('geld_verfügen', 18),
#  ('austausch', 18),
#  ('antragstellung', 18),
#  ('per_brief', 18),
#  ('zweimal', 18),
#  ('sollen', 18),
#  ('unterschreiten', 18),
#  ('effektiv_jahreszins', 18),
# ...

# %%
cw_s[3000:]
# Out:
# [('tagen', 11),
#  ('bargeldlose', 11),
#  ('transaktionskosten', 11),
#  ('transaktionsgebühr', 11),
#  ('kontakten', 11),
#  ('gestellt', 11),
#  ('wiederanlage', 11),
#  ('reduzierung', 11),
#  ('bevollmächtigter', 11),
#  ('oder-konto', 11),
#  ('gewinn', 11),
#  ('ankommen', 11),
#  ('tan-eingabe', 11),
#  ('teilnehmer', 11),
#  ('anlagedauer', 11),
#  ('börsenplatz', 11),
#  ('eigenständig', 11),
#  ('mobilgerät', 11),
#  ('internetbrowser', 11),
#  ('ausstellend_bank', 11),
#  ('antworten', 11),
#  ('depotgebühr', 11),
#  ('amerikanisch', 11),
#  ('breit', 11),
#  ('beruflich', 11),
#  ('nachvollziehbar', 11),
#  ('meinen', 11),
#  ('abstand', 11),
#  ('verfügung_gestellt', 11),
#  ('anbindung', 11),
#  ('updates', 11),
#  ('äußern', 11),
#  ('limitieren', 11),
#  ('großbritannien', 11),
#  ('euro-zahlungsverkehrsraum', 11),
#  ('vorläufig', 11),
#  ('zweifelsfall', 11),
#  ('umrechnung', 11),
#  ('maestro-girocard', 11),
#  ('entladen', 11),
#  ('freistellen', 11),
# ...

# %%
cw_s[4000:]
# Out:
# [('bankomat', 8),
#  ('webid', 8),
#  ('mobile"-app', 8),
#  ('multibanking', 8),
#  ('24-h-kundenservice', 8),
#  ('xi', 8),
#  ('didisparkonto', 8),
#  ('kfz-brief', 8),
#  ('finanzierungsvertrag', 8),
#  ('online-sicherheits-garantie', 8),
#  ('classic-karte', 8),
#  ('chargeback', 8),
#  ('geldkarten-chip', 8),
#  ('secoder', 8),
#  ('tilgungshöhe', 8),
#  ('wertpapierfirma', 8),
#  ('informiere', 8),
#  ('generalversammlung', 8),
#  ('check24', 8),
#  ('pushtan-app', 7),
#  ('verbieten', 7),
#  ('abhängigkeit', 7),
#  ('zugesandt', 7),
#  ('kontodetails', 7),
#  ('vermeintlich', 7),
#  ('ausliefern', 7),
#  ('onlinezugang', 7),
#  ('backup', 7),
#  ('vergehen', 7),
#  ('netscape', 7),
#  ('anerkennung', 7),
#  ('epostfach', 7),
#  ('privatsphäre', 7),
#  ('wasser', 7),
#  ('einzelpersonen', 7),
#  ('einzelunternehmer', 7),
#  ('hauptkonto', 7),
#  ('sms-service', 7),
#  ('herabsetzen', 7),
#  ('wiso', 7),
#  ('absehen', 7),
#  ('darlehenshöhe', 7),
#  ('mastercard-logo', 7),
# ...

# %%
model.most_similar('3d-secure',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('verified_by_visa_mastercard', 0.9623682498931885),
#  ('3d_secure', 0.9589182138442993),
#  ('verified_by_visa', 0.9545369744300842),
#  ('online-händler', 0.9542755484580994),
#  ('mastercard_securecode', 0.9463856816291809),
#  ('online-einkauf', 0.9427329897880554),
#  ('®_securecode_™', 0.9395281076431274),
#  ('3d_secure_verfahren', 0.9291867613792419),
#  ('mastercard_®_securecodetm', 0.9206363558769226),
#  ('einkaufen', 0.9176183342933655),
#  ('mastercard_®', 0.9140607118606567),
#  ('weiß', 0.9124432802200317),
#  ('mastercard_®_securecode_™', 0.905556321144104),
#  ('secure-verfahren', 0.9038366675376892),
#  ('ausstellend_bank', 0.9032996296882629),
#  ('secure', 0.9026792645454407),
# ...

# %%
model.most_similar('überweisung',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('tätig', 0.8443900942802429),
#  ('ausfahren', 0.8292133212089539),
#  ('inlandsüberweisung', 0.8135874271392822),
#  ('sepa-überweisung', 0.8005322217941284),
#  ('auftrag_geben', 0.7829064726829529),
#  ('auslandsüberweisung', 0.7755545973777771),
#  ('dienstag', 0.7669903039932251),
#  ('zahlungsauftrag', 0.7618663311004639),
#  ('empfänger', 0.7593091726303101),
#  ('gebucht', 0.7523603439331055),
#  ('buchen', 0.7519165277481079),
#  ('angegeben_referenzkonto', 0.7517237663269043),
#  ('lastschrift', 0.750849723815918),
#  ('empfängerbank', 0.7489763498306274),
#  ('stornieren', 0.7467054724693298),
#  ('sepa-format', 0.7363243699073792),
#  ('terminüberweisung', 0.7354254126548767),
# ...

# %%
model.most_similar('baukredit',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('zinskondition', 0.9489384293556213),
#  ('prinzipiell', 0.9455997943878174),
#  ('altersvorsorge', 0.9372355937957764),
#  ('werben', 0.9367278218269348),
#  ('günstig_zins', 0.9346657991409302),
#  ('expertenantwort', 0.9322510361671448),
#  ('bonitätsunabhängig', 0.9317144155502319),
#  ('annuitätendarlehen', 0.9316436648368835),
#  ('modernisierungskredit', 0.9314104914665222),
#  ('vielfach', 0.9304642081260681),
#  ('baugeld', 0.929007351398468),
#  ('umschuldungskredit', 0.9282428622245789),
#  ('infrage', 0.928144097328186),
#  ('effektivzinssatz', 0.9268893599510193),
#  ('baudarlehen', 0.9256868362426758),
#  ('immobiliendarlehen', 0.9251161217689514),
#  ('anfänglich', 0.9223884344100952),
# ...

# %%
model.most_similar('baufinanzierung',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('immobilienfinanzierung', 0.971439003944397),
#  ('finanzierung', 0.958290696144104),
#  ('umschuldungskredit', 0.937839925289154),
#  ('chance', 0.9346286654472351),
#  ('modernisierung', 0.9316597580909729),
#  ('immobilienkredit', 0.931207537651062),
#  ('autokredit', 0.9299217462539673),
#  ('umschuldung', 0.9299207329750061),
#  ('forward-darlehen', 0.9287327527999878),
#  ('günstig', 0.9275519847869873),
#  ('renovierung', 0.925673246383667),
#  ('annuitätendarlehen', 0.9254429340362549),
#  ('niedrig_zins', 0.9183748960494995),
#  ('anschlussfinanzierung', 0.9181675314903259),
#  ('finden_antwort', 0.9181317687034607),
#  ('darlehenszins', 0.9179896116256714),
#  ('kreditangebot', 0.9145562052726746),
# ...

# %%
model.most_similar('schufa',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('gespeichert_datum', 0.9202921986579895),
#  ('negative', 0.9144931435585022),
#  ('negativmerkmal', 0.8864301443099976),
#  ('kreditsicherung', 0.8858761191368103),
#  ('vertragspartner', 0.8801338076591492),
#  ('einholen', 0.8780588507652283),
#  ('schutzgemeinschaft', 0.8768997192382812),
#  ('schufa-auskunft', 0.8733083605766296),
#  ('auskunftei', 0.8705417513847351),
#  ('kreditanfrage', 0.8668774366378784),
#  ('allgemein', 0.8617489337921143),
#  ('vertragsgemäß', 0.8572705388069153),
#  ('negativ', 0.854777991771698),
#  ('auskunft', 0.8533105850219727),
#  ('verhalten', 0.8185251355171204),
#  ('weitergeben', 0.8037513494491577),
#  ('selbstauskunft', 0.8013096451759338),
# ...

# %%
model.most_similar('kreditkarte',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('kontaktlosfunktion', 0.826587975025177),
#  ('prepaid', 0.8078792691230774),
#  ('prepaid-karte', 0.7971642017364502),
#  ('kreditkartenanbieter', 0.7710590362548828),
#  ('paylife', 0.7685448527336121),
#  ('visa_card', 0.7661882638931274),
#  ('jahresgebühr', 0.7355388402938843),
#  ('classic', 0.7348995208740234),
#  ('verlust_diebstahl', 0.7347924709320068),
#  ('mastercard', 0.732151985168457),
#  ('ausstellung', 0.7301595211029053),
#  ('didibank_kreditkarte', 0.7259026169776917),
#  ('einkaufen', 0.7208762168884277),
#  ('akzeptanz', 0.7155913710594177),
#  ('virtuelle', 0.7148870229721069),
#  ('einkauf_internet', 0.7049306035041809),
#  ('ersatzkarte', 0.7029019594192505),
#  ('karte', 0.7020751237869263),
# ...

# %%
model.most_similar('freistellungsauftrag',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('freistellungsbetrag', 0.9346500039100647),
#  ('freistellungsauftrag_erteilen', 0.9195510149002075),
#  ('fsa', 0.9090843200683594),
#  ('erteilung', 0.8676723837852478),
#  ('ehepaare', 0.8465455174446106),
#  ('gemeinsam_freistellungsauftrag', 0.8414076566696167),
#  ('sparer-pauschbetrag', 0.8375435471534729),
#  ('freistellen', 0.8360869884490967),
#  ('trennung', 0.8282544612884521),
#  ('steuerabzug', 0.8192849159240723),
#  ('freistellungsauftrag_kapitalertrag', 0.8149013519287109),
#  ('vollmacht', 0.8113301992416382),
#  ('31.12', 0.8104448914527893),
#  ('heirat', 0.8076596856117249),
#  ('scheidung', 0.7977228760719299),
#  ('laufend_jahr', 0.7944157719612122),
#  ('elternteil', 0.7918238639831543),
# ...

# %%
model.most_similar('eigenkapital',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('renovierung', 0.9611024856567383),
#  ('darlehenszins', 0.9597464203834534),
#  ('eigenkapitalanteil', 0.9575300216674805),
#  ('objekt', 0.9514572024345398),
#  ('ausfallen', 0.9513719081878662),
#  ('immobilienkredit', 0.9478365778923035),
#  ('nämlich', 0.944354772567749),
#  ('langfristig', 0.9433308243751526),
#  ('modernisierung', 0.9402370452880859),
#  ('eigenheim', 0.9379907250404358),
#  ('ansetzen', 0.9374463558197021),
#  ('baudarlehen', 0.9359571933746338),
#  ('disagio', 0.9335682392120361),
#  ('vollfinanzierung', 0.9314765334129333),
#  ('anfänglich', 0.9306806325912476),
#  ('zeit', 0.929946780204773),
#  ('niedrig_zins', 0.9290950894355774),
#  ('wohneigentum', 0.9290350079536438),
# ...

# %%
model.most_similar('wertpapier',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('kaufen_verkaufen', 0.9082290530204773),
#  ('aktie', 0.894381582736969),
#  ('börse', 0.8461302518844604),
#  ('fond', 0.8449316620826721),
#  ('didibank_poltawien', 0.8364903330802917),
#  ('kauf', 0.8193792700767517),
#  ('stück', 0.8186373710632324),
#  ('handelbar', 0.8154955506324768),
#  ('bruchstück', 0.8068956136703491),
#  ('verkaufen', 0.8058417439460754),
#  ('verwahren', 0.8053930401802063),
#  ('investmentfonds', 0.7961522340774536),
#  ('anzahl', 0.7903093695640564),
#  ('neuemission', 0.777925968170166),
#  ('equiduct', 0.7769520878791809),
#  ('wertpapierdepot', 0.7758210301399231),
#  ('außerbörslichen', 0.7757412791252136),
#  ('etf', 0.7753103375434875),
#  ('anleger', 0.7717532515525818),
# ...

# %%
model.most_similar('geschäftskonto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('geschäftlich', 0.9038040041923523),
#  ('privatkonto', 0.8708676695823669),
#  ('führung', 0.8705708980560303),
#  ('onlinebank', 0.8665254712104797),
#  ('filialbank', 0.8524479269981384),
#  ('einzelunternehmer', 0.833747923374176),
#  ('selbstständige', 0.8247634768486023),
#  ('freiberufler', 0.8195172548294067),
#  ('basiskonto', 0.7886403203010559),
#  ('bereithalten', 0.7803404331207275),
#  ('fahren', 0.7705096006393433),
#  ('vereinen', 0.7683655023574829),
#  ('mikrokonto', 0.7615131735801697),
#  ('guthabenbereich', 0.7601398825645447),
#  ('online-banken', 0.7532356381416321),
#  ('privat', 0.7448816299438477),
#  ('kontoführungsgebühr', 0.7435680627822876),
#  ('hören', 0.7416874766349792),
# ...

# %%
model.most_similar('erteilen',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('erteilung', 0.847212553024292),
#  ('beauftragen', 0.8462490439414978),
#  ('einzugsermächtigung', 0.8420073390007019),
#  ('last', 0.7958056926727295),
#  ('vollmacht', 0.7861492037773132),
#  ('fsa', 0.7852827906608582),
#  ('formlos_schriftlich', 0.772697925567627),
#  ('widersprechen', 0.7697513103485107),
#  ('schriftlich', 0.7691779136657715),
#  ('anweisen', 0.7685136198997498),
#  ('vermerken', 0.7635310888290405),
#  ('angabe', 0.7610905766487122),
#  ('formlos', 0.7589330077171326),
#  ('sepa-lastschriftmandat', 0.7549360394477844),
#  ('freistellungsauftrag_erteilen', 0.7549276947975159),
#  ('lastschriftmandat', 0.7542769312858582),
#  ('montag', 0.7498107552528381),
# ...

# %%
model.most_similar('lastschrift',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('zurückgeben', 0.9158082604408264),
#  ('lastschriftverfahren', 0.9033849835395813),
#  ('widersprechen', 0.8722620010375977),
#  ('einziehen', 0.8666372299194336),
#  ('lastschrifteinzug', 0.866252601146698),
#  ('buchen', 0.842844545841217),
#  ('mangels', 0.8333993554115295),
#  ('einzug', 0.8303504586219788),
#  ('sepa-format', 0.8265337347984314),
#  ('sepa-lastschrift', 0.8260465264320374),
#  ('bankarbeitstag', 0.8221416473388672),
#  ('zahler', 0.8145142793655396),
#  ('rückgabe', 0.8088132739067078),
#  ('entgegennehmen', 0.7940045595169067),
#  ('empfängerkonto', 0.7920160889625549),
#  ('stornieren', 0.7910589575767517),
#  ('nacht', 0.7857634425163269),
#  ('empfängerbank', 0.7834503054618835),
# ...

# %%
model.most_similar('bank',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('kunde', 0.7464573979377747),
#  ('sparkasse', 0.6996378302574158),
#  ('verpflichten', 0.6575236320495605),
#  ('zahlungsunfähigkeit', 0.6479835510253906),
#  ('banken', 0.6263526082038879),
#  ('angehen', 0.6189600229263306),
#  ('gesetzlich_verpflichten', 0.6030002236366272),
#  ('finanzinstitut', 0.6000627279281616),
#  ('vertragspartner', 0.5914548635482788),
#  ('wertpapierfirma', 0.5884006023406982),
#  ('feststellen', 0.5862298607826233),
#  ('geschäftsbeziehung', 0.5851790308952332),
#  ('erklären', 0.5784152150154114),
#  ('bankkunde', 0.5678806900978088),
#  ('leihen', 0.5670255422592163),
#  ('alleinzeichnungsberechtigung', 0.5582815408706665),
#  ('weitergeben', 0.5566412806510925),
# ...

# %%
model.most_similar('steuern',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('abgeltungsteuer', 0.9436035752296448),
#  ('solidaritätszuschlag', 0.941691517829895),
#  ('beschließen', 0.9400553107261658),
#  ('ertrag', 0.9377890825271606),
#  ('steuerfrei', 0.9310113191604614),
#  ('abgeltungssteuer', 0.930757462978363),
#  ('realisieren', 0.9275622963905334),
#  ('finanzamt_abführen', 0.924496591091156),
#  ('gewinnen', 0.9230847954750061),
#  ('kursgewinne', 0.9206441044807434),
#  ('basiszinssatz', 0.916357159614563),
#  ('kapitalertragsteuer', 0.909358561038971),
#  ('besteuern', 0.9077007174491882),
#  ('einkunft_kapitalvermögen', 0.9072279930114746),
#  ('zuzüglich', 0.9028969407081604),
#  ('berücksichtigung', 0.900352954864502),
#  ('ags', 0.8996220231056213),
# ...

# %%
model.most_similar('p-konto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('pfändungsschutzkonto', 0.9429700970649719),
#  ('pfändungsschutz', 0.938284158706665),
#  ('pfändung', 0.9329043030738831),
#  ('kontopfändung', 0.8881454467773438),
#  ('p-konto_umwandeln', 0.8772304058074951),
#  ('pfändungsfreibetrag', 0.8583066463470459),
#  ('umwandlung', 0.8380416035652161),
#  ('guthabenbasis', 0.8346570730209351),
#  ('basisgirokonto', 0.8289980292320251),
#  ('pfänden', 0.817897617816925),
#  ('guthabenbereich', 0.8098077178001404),
#  ('gepfändet', 0.7835251092910767),
#  ('uneingeschränkt', 0.7800484895706177),
#  ('führen', 0.7791910767555237),
#  ('basiskonto', 0.7685863971710205),
#  ('meinen', 0.7626900672912598),
#  ('überziehen', 0.7574195861816406),
# ...

# %%
model.most_similar('kredit',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('darlehen', 0.8788995146751404),
#  ('ablösen', 0.8765883445739746),
#  ('autokredit', 0.8709723949432373),
#  ('zusammenfassen', 0.8615108132362366),
#  ('umschulden', 0.8598412871360779),
#  ('bestehend_kredit', 0.8547689914703369),
#  ('ratenkredit', 0.8534422516822815),
#  ('kreditgeber', 0.8521398901939392),
#  ('bewilligung', 0.8459740281105042),
#  ('kreditnehmer', 0.8438720703125),
#  ('bonität', 0.8407242894172668),
#  ('umschuldung', 0.8303734660148621),
#  ('bonitätsabhängig', 0.8264485597610474),
#  ('direktkredit', 0.8225276470184326),
#  ('zurückzahlen', 0.8132576942443848),
#  ('chance', 0.8128271698951721),
#  ('fahrzeugbrief', 0.8120297193527222),
#  ('sofortzusage', 0.8118770718574524),
# ...

# %%
model.most_similar('sparkonto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('sparbuch', 0.9622582197189331),
#  ('anlagekonto', 0.8996381163597107),
#  ('didi_tagesgeldkonto', 0.8985668420791626),
#  ('umbuchen', 0.8879637122154236),
#  ('tagesgeld', 0.8782129287719727),
#  ('tagesgeldkonto', 0.8759195804595947),
#  ('didisupersparkonto', 0.8753491044044495),
#  ('festgeldkonto', 0.8680333495140076),
#  ('tageskonto', 0.8575925230979919),
#  ('umbuchung', 0.8554204106330872),
#  ('didisparkonto', 0.8457406163215637),
#  ('kreditkartenkonto', 0.8418382406234741),
#  ('top-zinskonto', 0.8394882678985596),
#  ('einzahlung', 0.8357006907463074),
#  ('mindestanlagebetrag', 0.8356284499168396),
#  ('didi-sparkonto', 0.8350773453712463),
#  ('jugendtagesgeldkonto', 0.8340751528739929),
# ...

# %%
model.most_similar('gläubiger-id',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('gläubiger-identifikationsnummer', 0.9513790011405945),
#  ('lastschriftmandat', 0.8944074511528015),
#  ('sepa-lastschriftverfahren', 0.8509738445281982),
#  ('sepa-lastschriftmandat', 0.8462015390396118),
#  ('schriftform', 0.8327421545982361),
#  ('angabe', 0.8326917886734009),
#  ('lastschrifteinreicher', 0.832137942314148),
#  ('identifizierung', 0.8296769857406616),
#  ('mandat', 0.8271352052688599),
#  ('anschrift', 0.8177781701087952),
#  ('postident-coupon', 0.8152282238006592),
#  ('stammdaten', 0.8122201561927795),
#  ('personalausweis', 0.8081250786781311),
#  ('vorname', 0.8080217838287354),
#  ('kontoverbindung', 0.7998962998390198),
#  ('kontonummer_bankleitzahl', 0.7998559474945068),
# ...

# %%
model.most_similar('ebics',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('digital', 0.8713932037353516),
#  ('hbci', 0.8630266785621643),
#  ('banking-software', 0.8532900214195251),
#  ('vereinigt', 0.8335496783256531),
#  ('video-ident', 0.8324631452560425),
#  ('deutsche_bank', 0.8071706891059875),
#  ('internet-filiale', 0.8020115494728088),
#  ('idnow', 0.8002784252166748),
#  ('einzel', 0.7969239354133606),
#  ('bequem_hausen', 0.7958976030349731),
#  ('unterwegs', 0.7867162227630615),
#  ('profi', 0.784512996673584),
#  ('zugriff', 0.7824558615684509),
#  ('firma', 0.7809598445892334),
#  ('fints', 0.770226240158081),
#  ('einfach_bequem', 0.7673303484916687),
#  ('chipkarte', 0.7571690678596497),
#  ('cash', 0.7520211935043335),
#  ('schlüsseln', 0.7494231462478638),
# ...

# %%
model.most_similar('verfahren',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('chipkarte', 0.8126785755157471),
#  ('chiptan-verfahren', 0.7601166367530823),
#  ('speziell', 0.7491449117660522),
#  ('optic', 0.7379251718521118),
#  ('secoder', 0.7357117533683777),
#  ('video-ident', 0.735236406326294),
#  ('tan-generierung', 0.7337428331375122),
#  ('photo', 0.729025661945343),
#  ('funktionieren', 0.7253755331039429),
#  ('optisch', 0.7247595191001892),
#  ('hbci-verfahren', 0.7222930192947388),
#  ('tan-generator', 0.7186707258224487),
#  ('chiptan', 0.7108458876609802),
#  ('transaktionsnummer_tan', 0.7077368497848511),
#  ('bluetoothtan-verfahren', 0.7069860696792603),
#  ('nutzers', 0.7068721055984497),
#  ('plus-verfahren', 0.7063080668449402),
#  ('idnow', 0.7062925100326538),
# ...

# %%
model.most_similar('geld',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('transferieren', 0.7840521931648254),
#  ('überweisen', 0.7440062165260315),
#  ('sparen', 0.7384582757949829),
#  ('geldbetrag', 0.719256579875946),
#  ('sparguthaben', 0.6796140670776367),
#  ('abbuchen', 0.6751126646995544),
#  ('zurückbekommen', 0.6677892208099365),
#  ('beheben', 0.6661059856414795),
#  ('zahlungsverkehrskonto', 0.6597171425819397),
#  ('käuferschutz', 0.6594173908233643),
#  ('verfügbarkeit', 0.6517664790153503),
#  ('geld_verfügen', 0.6506218314170837),
#  ('didisparkonto-', 0.6449937224388123),
#  ('didisupersparkonto', 0.6438108086585999),
#  ('deckung', 0.6359909772872925),
#  ('sparbetrag', 0.6340298056602478),
#  ('einzahlung_auszahlung', 0.6339859366416931),
# ...

# %%
model.most_similar('kind',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('eltern', 0.9030002355575562),
#  ('minderjährig', 0.8890796899795532),
#  ('volljährig', 0.859919548034668),
#  ('lebensjahr', 0.8561930060386658),
#  ('18', 0.8547018766403198),
#  ('volljährigkeit', 0.8509347438812256),
#  ('jugendfestgeldkonto_jugend_kapital', 0.8428167104721069),
#  ('lebenspartner', 0.8332487344741821),
#  ('gemeinschaftskonto', 0.8288920521736145),
#  ('verfügungsberechtigung', 0.8222691416740417),
#  ('geburtsurkunde', 0.8204286694526672),
#  ('elternteil', 0.8113216161727905),
#  ('erwachsene', 0.8104196190834045),
#  ('gemeinschaftlich', 0.7977385520935059),
#  ('einzelkonto', 0.7961649298667908),
#  ('vollmachen', 0.793653666973114),
#  ('ehegatte', 0.7917054295539856),
# ...

# %%
model.most_similar('auto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('fahrzeug', 0.897921621799469),
#  ('situation', 0.8851871490478516),
#  ('nämlich', 0.8737769722938538),
#  ('arbeit', 0.8733087778091431),
#  ('bauherr', 0.8712465763092041),
#  ('klein', 0.8655168414115906),
#  ('modernisierung', 0.8646426200866699),
#  ('angesichts', 0.8608001470565796),
#  ('kraftfahrzeug', 0.8599957823753357),
#  ('erworben', 0.8595718145370483),
#  ('sicherlich', 0.8562840223312378),
#  ('müsste', 0.854832112789154),
#  ('schwer', 0.8516041040420532),
#  ('beleihungswert', 0.8511210083961487),
#  ('phase', 0.8483842015266418),
#  ('treuhänder', 0.8427867293357849),
#  ('bauen', 0.8427295088768005),
#  ('umstand', 0.8418236374855042),
#  ('gebäude', 0.8404962420463562),
# ...

# %%
model.most_similar('browser',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('internet_explorer', 0.9652501344680786),
#  ('explorer', 0.9621283411979675),
#  ('microsoft_internet', 0.9618480801582336),
#  ('firefox', 0.9489718675613403),
#  ('cookies', 0.948122501373291),
#  ('internetoptionen', 0.9415414333343506),
#  ('google_chrome', 0.936194121837616),
#  ('mozilla_firefox', 0.935398519039154),
#  ('safari', 0.9353830814361572),
#  ('script', 0.931316614151001),
#  ('netscape', 0.9256907105445862),
#  ('add-ons', 0.9191957116127014),
#  ('aktuell_version', 0.9185014963150024),
#  ('betriebssystem', 0.9145439267158508),
#  ('rechner', 0.9143240451812744),
#  ('internetbrowser', 0.9118988513946533),
#  ('adresszeile', 0.9115324020385742),
#  ('microsoft', 0.9099648594856262),
# ...

# %%
model.most_similar('pin',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('vierstellige', 0.8389531373977661),
#  ('persönlich_geheimzahl', 0.8339585661888123),
#  ('zahlenkombination', 0.8321635723114014),
#  ('geheimzahl', 0.8228124380111694),
#  ('kontozugang', 0.8211879730224609),
#  ('geheimnummer', 0.8171780705451965),
#  ('pin_ändern', 0.8160773515701294),
#  ('hintereinander', 0.8158268928527832),
#  ('t-pin', 0.8073216676712036),
#  ('fehlversuch', 0.802015483379364),
#  ('erstmalig', 0.8012624382972717),
#  ('verfügername', 0.8010435104370117),
#  ('pin_vergessen', 0.79962158203125),
#  ('wunsch-pin', 0.7991485595703125),
#  ('mpin', 0.7969673871994019),
#  ('anmeldename', 0.7895308136940002),
#  ('identifikationsnummer', 0.7845206260681152),
# ...

# %%
model.most_similar('fatca',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('common_reporting', 0.9742845296859741),
#  ('crs', 0.9698920845985413),
#  ('act', 0.9695086479187012),
#  ('foreign', 0.9624040126800537),
#  ('standard_crs', 0.9621992707252502),
#  ('abkommen', 0.960922360420227),
#  ('compliance', 0.9572751522064209),
#  ('tax', 0.9525285363197327),
#  ('oecd', 0.9505431652069092),
#  ('bundesrepublik', 0.9475985765457153),
#  ('steuerhinterziehung', 0.9433674812316895),
#  ('verordnung', 0.9275715351104736),
#  ('vorschrift', 0.926400363445282),
#  ('steuerbehörde', 0.9260072112083435),
#  ('ansässig', 0.9206550717353821),
#  ('artikel', 0.9188242554664612),
#  ('deutschen', 0.9179496765136719),
#  ('bundesverband', 0.9158654808998108),
# ...

# %%
model.most_similar('festgeldkonto',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('festgeld', 0.9454565644264221),
#  ('anlagebetrag', 0.9443841576576233),
#  ('jugendtagesgeldkonto', 0.9303069710731506),
#  ('didi_tagesgeldkonto', 0.9259352684020996),
#  ('tagesgeld', 0.9172598719596863),
#  ('verrechnungskonto', 0.9136201739311218),
#  ('didi-sparkonto', 0.9134034514427185),
#  ('tageskonto', 0.8974393010139465),
#  ('didisupersparkonto', 0.8947919011116028),
#  ('kombi', 0.8934964537620544),
#  ('didisparkonto', 0.8899769186973572),
#  ('online-festgeld', 0.8882125020027161),
#  ('festgeldanlage', 0.8872083425521851),
#  ('auflösen', 0.8847653865814209),
#  ('auflösung', 0.8838656544685364),
#  ('jugend', 0.8837947845458984),
#  ('tagesgeldkonto', 0.8835954666137695),
# ...

# %%
kunles = model.infer_vector(["karten", "lesbar", "Ursache"])

# %%
kunles
# Out:
# array([-6.01542124e-04, -2.08204351e-02, -3.38037424e-02, -1.32248327e-02,
#         6.38039084e-03, -5.35096833e-03, -1.38024578e-03, -9.81889293e-03,
#         1.08305905e-02, -4.11532586e-03, -1.92840490e-02,  4.71631764e-03,
#        -3.29861268e-02, -1.50915822e-02, -8.83420464e-03, -2.27586087e-02,
#        -1.67138521e-02, -4.49953089e-03,  5.58228092e-03, -1.65505651e-02,
#         1.08108530e-02,  2.46766247e-02, -1.58214308e-02, -1.01059312e-02,
#         1.55931292e-03, -2.27286443e-02,  1.10990368e-02, -5.25650103e-03,
#        -2.40579178e-03,  2.57538725e-02,  1.46203302e-02,  4.32707183e-03,
#         9.30635259e-03,  2.19051205e-02,  8.30448139e-03, -1.16808526e-03,
#         8.56870692e-03, -1.76808406e-02,  8.43582209e-03, -3.68487611e-02,
#        -1.15430849e-02,  9.66035388e-03,  2.77768332e-03,  1.41237210e-02,
#         3.86837870e-02, -1.29144434e-02,  1.39534974e-03,  2.05890518e-02,
# ...

# %%
model.docvecs.most_similar([kunles])
# Out:
# [(6564, 0.9077324867248535),
#  (977, 0.8967280983924866),
#  (3771, 0.8963473439216614),
#  (5768, 0.8959888219833374),
#  (5420, 0.8929585814476013),
#  (5391, 0.8919814825057983),
#  (5602, 0.8909286260604858),
#  (4822, 0.8898705244064331),
#  (753, 0.8892862796783447),
#  (5188, 0.8859850764274597)]

# %%
model.docvecs.most_similar([0])
# Out:
# [(307, 0.976145327091217),
#  (9, 0.9563352465629578),
#  (3685, 0.8731504678726196),
#  (1995, 0.8705720901489258),
#  (4210, 0.870022177696228),
#  (1203, 0.8640402555465698),
#  (6772, 0.8600032925605774),
#  (3001, 0.8531690239906311),
#  (8, 0.8524026274681091),
#  (4095, 0.8507428765296936)]

# %%
model.docvecs.most_similar([4228])
# Out:
# [(2461, 0.9470325708389282),
#  (2018, 0.934284508228302),
#  (1113, 0.9285637736320496),
#  (2192, 0.9283607602119446),
#  (3075, 0.9246450066566467),
#  (4883, 0.9243336915969849),
#  (31, 0.9205955862998962),
#  (7022, 0.9203730225563049),
#  (18, 0.9198610186576843),
#  (458, 0.919672429561615)]

# %%
model.docvecs.most_similar([3])
# Out:
# [(16, 0.9928759932518005),
#  (2815, 0.9612928628921509),
#  (6863, 0.9550360441207886),
#  (28, 0.9533913135528564),
#  (2816, 0.9411435127258301),
#  (13, 0.940769612789154),
#  (27, 0.9328815340995789),
#  (6111, 0.9299950003623962),
#  (7165, 0.9285071492195129),
#  (2456, 0.9222067594528198)]

# %%
model.docvecs.most_similar([4270])
# Out:
# [(2303, 0.8288490772247314),
#  (6511, 0.7936197519302368),
#  (1388, 0.7611179351806641),
#  (1104, 0.7421602606773376),
#  (5672, 0.7329140901565552),
#  (422, 0.6831761002540588),
#  (1407, 0.6630647778511047),
#  (893, 0.65440833568573),
#  (675, 0.6543777585029602),
#  (3731, 0.6536858677864075)]

# %%
model.most_similar('telefonnummer',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('anrufen', 0.9384151101112366),
#  ('phone', 0.9295955300331116),
#  ('telefon', 0.9190214276313782),
#  ('telefon-pin', 0.899736225605011),
#  ('kunden-service-center', 0.8990291953086853),
#  ('kundenservice', 0.8944496512413025),
#  ('rufnummer', 0.8925386667251587),
#  ('anruf', 0.8777820467948914),
#  ('kundenbetreuer', 0.8744988441467285),
#  ('electronicbanking-hotline', 0.8688599467277527),
#  ('kontaktieren_kundenservice', 0.8685461282730103),
#  ('service_center', 0.8674805164337158),
#  ('wende', 0.866919755935669),
#  ('ruf', 0.8661456108093262),
#  ('24h-kundenservice', 0.8606180548667908),
#  ('halt', 0.8477580547332764),
#  ('montag_freitag', 0.8438199758529663),
# ...

# %%
model.most_similar('video-ident',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('idnow', 0.9785120487213135),
#  ('identitätsfeststellung', 0.91771399974823),
#  ('video-legitimation', 0.9148367047309875),
#  ('geldwäschegesetz', 0.9017734527587891),
#  ('bequem_hausen', 0.8983653783798218),
#  ('videoident-verfahren', 0.8814550638198853),
#  ('brauche', 0.8800837993621826),
#  ('identitätsprüfung_per_video', 0.8757327198982239),
#  ('offiziell', 0.8705827593803406),
#  ('deutschen_post', 0.868310272693634),
#  ('postident_verfahren', 0.8615947961807251),
#  ('postid', 0.8615795969963074),
#  ('identifikation', 0.8605261445045471),
#  ('postident', 0.8551704287528992),
#  ('schnellen_einfach', 0.8547151684761047),
#  ('vr-networld', 0.8521689772605896),
#  ('herstellen', 0.8513247966766357),
# ...

# %%
model.most_similar('kunde',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('bank', 0.7464573979377747),
#  ('kundin', 0.6881400942802429),
#  ('eg', 0.6412104964256287),
#  ('sparkasse', 0.6312522888183594),
#  ('banken', 0.6310914158821106),
#  ('direktbank', 0.5907905101776123),
#  ('umsetzen', 0.5895839333534241),
#  ('wertpapierfirma', 0.588452935218811),
#  ('einfahren', 0.5778990983963013),
#  ('united', 0.5720124840736389),
#  ('schonen', 0.5719774961471558),
#  ('angehen', 0.5659515261650085),
#  ('finanzinstitut', 0.5571960210800171),
#  ('didibank_bank_poltawien-poltawien', 0.5512349605560303),
#  ('s.a.', 0.5501685738563538),
#  ('überzeugen', 0.5397394299507141),
#  ('rasch', 0.5376781225204468),
#  ('dienstleistung', 0.5370205640792847),
#  ('unternehmen', 0.5368886590003967),
# ...

# %%
model.most_similar('passwort',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('erraten', 0.8827762007713318),
#  ('merken', 0.849037766456604),
#  ('anmeldename', 0.8443278670310974),
#  ('vierstellige', 0.8386361598968506),
#  ('erst-pin', 0.83799809217453),
#  ('wort', 0.833069920539856),
#  ('kombination', 0.8168838024139404),
#  ('masterpasswort', 0.8144934177398682),
#  ('benutzername', 0.8030958771705627),
#  ('shortpin', 0.8023326992988586),
#  ('geheim', 0.7947767376899719),
#  ('kennwort', 0.7938129305839539),
#  ('hintereinander', 0.7932214140892029),
#  ('speicher', 0.7923906445503235),
#  ('password', 0.7920331358909607),
#  ('niemals', 0.791938304901123),
#  ('zurücksetzen', 0.7840791940689087),
#  ('selbstgewählte', 0.7818794250488281),
#  ('fehlversuch', 0.7818756103515625),
# ...

# %%
model.most_similar('dauerauftrag',topn=100)
# Out:
# /home/diego/anaconda3/envs/bankdomain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('ändern_löschen', 0.9095796346664429),
#  ('terminüberweisung', 0.8845040202140808),
#  ('auftragslisten', 0.8440213203430176),
#  ('überweisungslimit', 0.8211370706558228),
#  ('umbuchung', 0.7962806224822998),
#  ('ausfahren', 0.7919704914093018),
#  ('stornieren', 0.7883996963500977),
#  ('schließung', 0.7840535640716553),
#  ('wertpapiersparplan', 0.7793817520141602),
#  ('unterkonto', 0.7719001173973083),
#  ('zurückrufen', 0.7698089480400085),
#  ('dienstag', 0.769173800945282),
#  ('kontenübersicht', 0.763685405254364),
#  ('buchen', 0.7623382806777954),
#  ('auftrag_geben', 0.762152910232544),
#  ('kontoübersicht', 0.7560408115386963),
#  ('sepa-format', 0.7553588151931763),
# ...
